# %% [markdown]
# get YOLO26 dataset

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="FDhrpsYuqgF7mTqlJ3wF")
project = rf.workspace("throwandcatch").project("tennis-ball-validation")
version = project.version(1)
dataset = version.download("yolo26")
# Out:
# ...
#   Using cached opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# ...
# Using cached opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.9 MB)
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to tennis-ball-validation-1 in yolo26:: 100%|██████████| 411/411 [00:00<00:00, 8152.33it/s]

# %% [markdown]
# get YOLO11 dataset

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="FDhrpsYuqgF7mTqlJ3wF")
project = rf.workspace("throwandcatch").project("tennis-ball-validation")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to tennis-ball-validation-1 in yolov11:: 100%|██████████| 411/411 [00:00<00:00, 9954.20it/s]
