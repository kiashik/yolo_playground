# %% [markdown]
# get YOLO26 dataset

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="FDhrpsYuqgF7mTqlJ3wF")
project = rf.workspace("throwandcatch").project("tennis-ball-in-lab")
version = project.version(4)
dataset = version.download("yolo26")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Tennis-ball-in-lab-4 in yolo26:: 100%|██████████| 1010/1010 [00:00<00:00, 7004.25it/s]

# %% [markdown]
# get YOLO11 dataset

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="FDhrpsYuqgF7mTqlJ3wF")
project = rf.workspace("throwandcatch").project("tennis-ball-in-lab")
version = project.version(4)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Tennis-ball-in-lab-4 in yolov11:: 100%|██████████| 1010/1010 [00:00<00:00, 7125.85it/s]
